# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Colored Scatterd Plots

# %%
iris = pd.read_csv("C:\\Users\\sarayu krishna\\Downloads\\iris.csv")
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'])
plt.xlabel('SepalLength')
plt.ylabel('PetalLength')
# Out:
# Text(0, 0.5, 'PetalLength')

# %%
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 45    46            4.8           3.0            1.4           0.3
# 42    43            4.4           3.2            1.3           0.2
# 149  150            5.9           3.0            5.1           1.8
# 113  114            5.7           2.5            5.0           2.0
# 133  134            6.3           2.8            5.1           1.5
#
#             Species
# 45      Iris-setosa
# 42      Iris-setosa
# 149  Iris-virginica
# 113  Iris-virginica
# 133  Iris-virginica

# %%
iris['Species'] = iris['Species'].replace({'Iris-versicolor':0,'Iris-virginica':1,'Iris-setosa':2})
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 74    75            6.4           2.9            4.3           1.3        0
# 25    26            5.0           3.0            1.6           0.2        2
# 70    71            5.9           3.2            4.8           1.8        0
# 140  141            6.7           3.1            5.6           2.4        1
# 90    91            5.5           2.6            4.4           1.2        0

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='summer',alpha=0.75)   # cmap for theme,alpha for opacity 
plt.xlabel('SepalLength')
plt.ylabel('PetalLength')
plt.colorbar()

# %%
plt.figure(figsize=(15,8))
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='summer',alpha=0.75)   # cmap for theme,alpha for opacity 
plt.xlabel('SepalLength')
plt.ylabel('PetalLength')
plt.colorbar()

# %%
batters= pd.read_csv("C:\\Users\\sarayu krishna\\Downloads\\batter.csv")
batters.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
sample_df = batters.head(100).sample(25, random_state=5)

# %%
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.scatter(sample_df['avg'],sample_df['strike_rate'])

# %%
plt.figure(figsize=(18,10))
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])
for i  in range(sample_df.shape[0]):                     #when you use [0] after shape, it retrieves just the number of rows.
   plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])   #annotate the graph acc to (xcor,ycor,namecol)

# %%
plt.figure(figsize=(18,10))
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])
plt.axhline(125,color='yellow')
plt.axvline(30)
for i  in range(sample_df.shape[0]):                     #when you use [0] after shape, it retrieves just the number of rows.
   plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])   #annotate the graph acc to (xcor,ycor,namecol)

# %% [markdown]
# ## Subplots

# %%
fig,ax = plt.subplots()

# %%
fig,ax = plt.subplots(figsize=(15,6))
ax.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])
ax.set_title('fertc')
ax.set_xlabel('avg')
ax.set_xlabel('strike_rate')
# Out:
# Text(0.5, 0, 'strike_rate')

# %%
plt.subplots(nrows=2,ncols=1)
# Out:
# (<Figure size 640x480 with 2 Axes>, array([<Axes: >, <Axes: >], dtype=object))

# %%
fig,ax= plt.subplots(nrows=2,ncols=1)

# %%
ax[0]
# Out:
# <Axes: >

# %%
fig,ax= plt.subplots(nrows=2,ncols=1,sharex=True)
ax[0].scatter(sample_df['avg'],sample_df['strike_rate'])
ax[1].scatter(sample_df['avg'],sample_df['runs'])
ax[0].set_ylabel('strike rate')
ax[1].set_ylabel('runs')
ax[1].set_xlabel('avg')
# Out:
# Text(0.5, 0, 'avg')

# %%
fig = plt.figure()
ax1=fig.add_subplot(2,1,1)
ax1.scatter(sample_df['avg'],sample_df['strike_rate'])
ax1=fig.add_subplot(2,1,2)
ax1.scatter(sample_df['avg'],sample_df['runs'])

# %% [markdown]
# ## 3D Scatter Plots

# %%
ax= plt.figure()
ax=plt.subplot(projection='3d')
ax.scatter3D(batters['runs'],batters['avg'],batters['strike_rate'],marker='+')
ax.set_title('batsman analysis')
ax.set_xlabel('runs')
ax.set_ylabel('avg')
ax.set_zlabel('sr')
# Out:
# Text(0.5, 0, 'sr')

# %% [markdown]
# ## 3DLine Plot

# %%
x=[14,20,30]
y=[18,25,36]
z=[7,8,12]
ax=plt.subplot(projection='3d')
ax.scatter3D(x,y,z,s=[100,100,100])
ax.plot3D(x,y,z,color='red')

# %% [markdown]
# ## 3D SURFACE PLOT

# %%
x=np.linspace(-10,10,100)
y=np.linspace(-10,10,100)

# %%
xx,yy = np.meshgrid(x,y)
##print("xx:\n", xx)
##print("yy:\n", yy)
# Out:
# xx:
#  [[-10.         -9.7979798  -9.5959596 ...   9.5959596   9.7979798
#    10.       ]
#  [-10.         -9.7979798  -9.5959596 ...   9.5959596   9.7979798
#    10.       ]
#  [-10.         -9.7979798  -9.5959596 ...   9.5959596   9.7979798
#    10.       ]
#  ...
#  [-10.         -9.7979798  -9.5959596 ...   9.5959596   9.7979798
#    10.       ]
#  [-10.         -9.7979798  -9.5959596 ...   9.5959596   9.7979798
#    10.       ]
#  [-10.         -9.7979798  -9.5959596 ...   9.5959596   9.7979798
#    10.       ]]
# yy:
#  [[-10.        -10.        -10.        ... -10.        -10.
#   -10.       ]
#  [ -9.7979798  -9.7979798  -9.7979798 ...  -9.7979798  -9.7979798
#    -9.7979798]
#  [ -9.5959596  -9.5959596  -9.5959596 ...  -9.5959596  -9.5959596
#    -9.5959596]
#  ...
#  [  9.5959596   9.5959596   9.5959596 ...   9.5959596   9.5959596
#     9.5959596]
#  [  9.7979798   9.7979798   9.7979798 ...   9.7979798   9.7979798
#     9.7979798]
# ...

# %%
z=xx**2 + yy**2
z.shape
# Out:
# (100, 100)

# %%
z = np.sin(xx) + np.cos(yy)
fig = plt.figure(figsize=(15,8))
ax = plt.subplot(projection='3d')
p = ax.plot_surface(xx, yy, z, cmap='viridis')
fig.colorbar(p)

# %% [markdown]
# ## Contour plot

# %%
fig = plt.figure(figsize=(15,8))
ax = plt.subplot( )
p = ax.contour(xx, yy, z, cmap='viridis')
fig.colorbar(p)

# %% [markdown]
# fig = plt.figure(figsize=(15,8))
# ax = plt.subplot( )
# p = ax.contourf(xx, yy, z, cmap='viridis')
# fig.colorbar(p)

# %% [markdown]
# ## HeatMAP

# %%
delivery = pd.read_csv("C:\\Users\\sarayu krishna\\Downloads\\IPL_Ball_by_Ball_2008_2022.csv")
delivery.head()
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN            0           0          0             0
# 1   JC Buttler    legbyes            0           1          1             0
# 2  YBK Jaiswal        NaN            1           0          1             0
# 3   JC Buttler        NaN            0           0          0             0
# 4   JC Buttler        NaN            0           0          0             0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# ...

# %%
# Program to plot 2-D Heat map 
 

data = np.random.random((12, 12)) 
plt.imshow(data, cmap='autumn') 

plt.title("Heatmap with different color") 
plt.show()

# %% [markdown]
# ## Pandas plot

# %%
# on series
s = pd.Series([1,2,3,4,8])
s.plot(kind='line' )
# Out:
# <Axes: >

# %%
import seaborn as sns
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips['size'] = tips['size']*100

# %%
x=tips.plot(kind='scatter', x='total_bill',y='tip',title=' cost analysis',color='red',marker='+',s='size')

# %%
x=tips.plot(kind='scatter', x='total_bill',y='tip',title=' cost analysis',marker='+',s='size',c='sex',cmap='viridis')

# %%
# 2d plot
# dataset = 'https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv'

stocks = pd.read_csv('https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv')
stocks.head()
# Out:
#          Date        MSFT          FB        AAPL
# 0  2021-05-24  249.679993  328.730011  124.610001
# 1  2021-05-31  250.789993  330.350006  125.889999
# 2  2021-06-07  257.890015  331.260010  127.349998
# 3  2021-06-14  259.429993  329.660004  130.460007
# 4  2021-06-21  265.019989  341.369995  133.110001

# %%
# line plot
stocks['MSFT'].plot(kind='line')
# Out:
# <Axes: >

# %%
# line plot
stocks.plot(kind='line')
# Out:
# <Axes: >

# %%
# line plot
stocks[['MSFT','AAPL']].plot(kind='line')
# Out:
# <Axes: >

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   200
# 1         10.34  1.66    Male     No   Sun  Dinner   300
# 2         21.01  3.50    Male     No   Sun  Dinner   300
# 3         23.68  3.31    Male     No   Sun  Dinner   200
# 4         24.59  3.61  Female     No   Sun  Dinner   400
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner   300
# 240       27.18  2.00  Female    Yes   Sat  Dinner   200
# 241       22.67  2.00    Male    Yes   Sat  Dinner   200
# 242       17.82  1.75    Male     No   Sat  Dinner   200
# 243       18.78  3.00  Female     No  Thur  Dinner   200
#
# [244 rows x 7 columns]

# %%
tips.plot(kind='bar',x='sex',y='total_bill')
# Out:
# <Axes: xlabel='sex'>

# %%
tips.groupby('sex')['total_bill'].mean().plot(kind='bar') # the first command gives you an aggregated view (mean total bill by sex), while the second command tries to plot all individual data points, which usually isn’t useful when ‘x’ is a categorical variable like ‘sex’.
# Out:
# C:\Users\sarayu krishna\AppData\Local\Temp\ipykernel_4452\1235535362.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   tips.groupby('sex')['total_bill'].mean().plot(kind='bar') # the first command gives you an aggregated view (mean total bill by sex), while the second command tries to plot all individual data points, which usually isn’t useful when ‘x’ is a categorical variable like ‘sex’.
# <Axes: xlabel='sex'>

# %%
temp = pd.read_csv("C:\\Users\\sarayu krishna\\Downloads\\batsman_season_record.csv")
temp
# Out:
#           batsman  2015  2016  2017
# 0  AB de Villiers   513   687   216
# 1       DA Warner   562   848   641
# 2        MS Dhoni   372   284   290
# 3       RG Sharma   482   489   333
# 4         V Kohli   505   973   308

# %%
temp['2015'].plot(kind = 'bar')
# Out:
# <Axes: >

# %%
temp.plot(kind = 'bar',stacked=True)
# Out:
# <Axes: >

# %%
stocks
# Out:
#           Date        MSFT          FB        AAPL
# 0   2021-05-24  249.679993  328.730011  124.610001
# 1   2021-05-31  250.789993  330.350006  125.889999
# 2   2021-06-07  257.890015  331.260010  127.349998
# 3   2021-06-14  259.429993  329.660004  130.460007
# 4   2021-06-21  265.019989  341.369995  133.110001
# 5   2021-06-28  277.649994  354.700012  139.960007
# 6   2021-07-05  277.940002  350.420013  145.110001
# 7   2021-07-12  280.750000  341.160004  146.389999
# 8   2021-07-19  289.670013  369.790009  148.559998
# 9   2021-07-26  284.910004  356.299988  145.860001
# 10  2021-08-02  289.459991  363.510010  146.139999
# 11  2021-08-09  292.850006  363.179993  149.100006
# 12  2021-08-16  304.359985  359.369995  148.190002
# 13  2021-08-23  299.720001  372.630005  148.600006
# 14  2021-08-30  301.140015  376.260010  154.300003
# 15  2021-09-06  295.709991  378.690002  148.970001
# 16  2021-09-13  299.869995  364.720001  146.059998
# ...

# %%
stocks.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df = pd.DataFrame(
    {
        'batsman':['Dhawan','Rohit','Kohli','SKY','Pandya','Pant'],
        'match1':[120,90,35,45,12,10],
        'match2':[0,1,123,130,34,45],
        'match3':[50,24,145,45,10,90]
    }
)

df.head()
# Out:
#   batsman  match1  match2  match3
# 0  Dhawan     120       0      50
# 1   Rohit      90       1      24
# 2   Kohli      35     123     145
# 3     SKY      45     130      45
# 4  Pandya      12      34      10

# %%
df['match1'].plot(kind='pie',labels=df['batsman'].values,autopct='%0.1f%%')
# Out:
# <Axes: ylabel='match1'>

# %%
df[['match1','match2','match3']].plot(kind='pie',subplots=True)
# Out:
# array([<Axes: ylabel='match1'>, <Axes: ylabel='match2'>,
#        <Axes: ylabel='match3'>], dtype=object)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner   200
# 1         10.34  1.66    Male     No   Sun  Dinner   300
# 2         21.01  3.50    Male     No   Sun  Dinner   300
# 3         23.68  3.31    Male     No   Sun  Dinner   200
# 4         24.59  3.61  Female     No   Sun  Dinner   400
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner   300
# 240       27.18  2.00  Female    Yes   Sat  Dinner   200
# 241       22.67  2.00    Male    Yes   Sat  Dinner   200
# 242       17.82  1.75    Male     No   Sat  Dinner   200
# 243       18.78  3.00  Female     No  Thur  Dinner   200
#
# [244 rows x 7 columns]

# %%
tips.pivot_table(index=['day','time'],columns=['sex','smoker'],values='total_bill',aggfunc='mean').plot(kind='line')
# Out:
# C:\Users\sarayu krishna\AppData\Local\Temp\ipykernel_4452\1122339873.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   tips.pivot_table(index=['day','time'],columns=['sex','smoker'],values='total_bill',aggfunc='mean').plot(kind='line')
# <Axes: xlabel='day,time'>
